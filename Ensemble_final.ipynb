# %%
import matplotlib.pyplot as plt
import numpy as np
import PIL
import tensorflow as tf
import pathlib
import os
import pandas as pd
from tensorflow import keras
from tensorflow.keras.models import Sequential
from IPython.display import Image
from keras import metrics
from sklearn.metrics import ConfusionMatrixDisplay
from tensorflow.keras import datasets, layers, models, losses
from tensorflow.keras.layers import Dropout, GlobalMaxPooling2D, Dense, Flatten, GlobalAveragePooling2D
import tf_keras
from tensorflow.keras.callbacks import EarlyStopping
import os
#os.environ['TF_USE_LEGACY_KERAS'] = '1'
from tensorflow.keras.layers import Layer, Concatenate, Input

from sklearn.metrics import accuracy_score

from keras.models import Model
from keras.optimizers import SGD, Adam
tf.random.set_seed(1234)

# %% [markdown]
# ## Load Data

# %%
# %%capture
import zipfile
# !unzip /content/CIFAKE.zip

# %%
dataset_dir = "train"
img_height = 32
img_width = 32
batch_size = 500

# Load training and validation data
train, val = keras.utils.image_dataset_from_directory(
  os.path.join(dataset_dir, ""),
  validation_split=0.2,
  subset="both",
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = 500)
# Out:
# Found 100000 files belonging to 2 classes.
# Using 80000 files for training.
# Using 20000 files for validation.

# %%
test = keras.utils.image_dataset_from_directory(
  os.path.join("test"),
  seed = 512,
  image_size = (img_height, img_width),
  batch_size = 500)
# Out:
# Found 20000 files belonging to 2 classes.

# %%
train_list = list(train)
train_imgs = train_list[0][0].numpy()
train_labels = train_list[0][1].numpy()
norm_train_imgs = train_imgs/255.0
norm_train_imgs.shape
# Out:
# (500, 32, 32, 3)

# %%
val_list = list(val)
val_imgs = val_list[0][0].numpy()
val_labels = val_list[0][1].numpy()
norm_val_imgs = val_imgs/255.0
val_labels.shape
# Out:
# (500,)

# %%
test_list = list(test)
test_imgs = test_list[0][0].numpy()
test_labels = test_list[0][1].numpy()
norm_test_imgs = test_imgs/255.0
norm_test_imgs.shape
# Out:
# (500, 32, 32, 3)

# %% [markdown]
# ## CNN

# %%
keras.backend.clear_session()

cnn_model = Sequential([
    layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
    layers.Conv2D(filters=64, kernel_size=3, activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),
    layers.Conv2D(filters=128, kernel_size=3, activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),
    layers.Conv2D(filters=256, kernel_size=3, activation="relu", padding="same"),
    layers.MaxPooling2D(),
    layers.Dropout(0.4),
    layers.Flatten(),
    layers.Dense(units=512, activation="relu"),
    layers.Dense(units=1, activation="sigmoid")])

# %%
cnn_model.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy", metrics.Precision(name="precision"), metrics.Recall(name="recall")])
es = EarlyStopping(monitor="val_accuracy",
                   patience=10,
                   restore_best_weights=True,
                   verbose=1)

# %%
epochs = 80

history = cnn_model.fit(
  train,
  validation_data=val,
  epochs=epochs,
  verbose=3,
  callbacks=es)

history = pd.DataFrame(history.history)
pd.set_option("display.max_rows", 80)
display(history)
# Out:
# Epoch 1/80
# Epoch 2/80
# Epoch 3/80
# Epoch 4/80
# Epoch 5/80
# Epoch 6/80
# Epoch 7/80
# Epoch 8/80
# Epoch 9/80
# Epoch 10/80
# Epoch 11/80
# Epoch 12/80
# Epoch 13/80
# Epoch 14/80
# Epoch 15/80
# Epoch 16/80
# Epoch 17/80
# Epoch 18/80
# Epoch 19/80
# Epoch 20/80
# Epoch 21/80
# Epoch 22/80
# Epoch 23/80
# Epoch 24/80
# Epoch 25/80
# Epoch 26/80
# Epoch 27/80
# Epoch 28/80
# Epoch 29/80
# Epoch 30/80
# Epoch 31/80
# Epoch 32/80
# Epoch 33/80
# Epoch 34/80
# Epoch 35/80
# Epoch 36/80
# Epoch 37/80
# Epoch 38/80
# Epoch 39/80
# Epoch 40/80
# Epoch 41/80
# Epoch 42/80
# Epoch 43/80
# Epoch 44/80
# Epoch 45/80
# Restoring model weights from the end of the best epoch: 35.
# Epoch 45: early stopping
#         loss  accuracy  precision    recall  val_loss  val_accuracy  \
# 0   0.485142  0.756550   0.770360  0.730749  0.326451       0.86820
# 1   0.299034  0.874800   0.867096  0.885182  0.254625       0.89885
# 2   0.245344  0.899650   0.895811  0.904414  0.217029       0.91385
# 3   0.217225  0.911462   0.909412  0.913893  0.199006       0.92120
# 4   0.205454  0.917313   0.914720  0.920370  0.173337       0.93435
# 5   0.198137  0.920575   0.918161  0.923396  0.181286       0.93050
# 6   0.179898  0.929462   0.927991  0.931124  0.171139       0.93205
# 7   0.170145  0.932400   0.931878  0.932950  0.142500       0.94570
# 8   0.168113  0.932913   0.931689  0.934275  0.142447       0.94675
# 9   0.159155  0.936787   0.936099  0.937527  0.144073       0.94460
# 10  0.149723  0.941513   0.939939  0.943254  0.158286       0.93830
# 11  0.145668  0.942788   0.942844  0.942679  0.127588       0.95270
# 12  0.144866  0.942925   0.941887  0.944054  0.148638       0.94210
# 13  0.138820  0.944812   0.944247  0.945405  0.120805       0.95395
# 14  0.127914  0.950063   0.948932  0.951282  0.119126       0.95450
# 15  0.126698  0.950725   0.949560  0.951982  0.138475       0.94650
# 16  0.124709  0.951450   0.950755  0.952182  0.125129       0.95125
# 17  0.121470  0.952937   0.952366  0.953533  0.115588       0.95615
# 18  0.118972  0.953888   0.953428  0.954358  0.111777       0.95810
# 19  0.118660  0.953775   0.952897  0.954708  0.116274       0.95505
# 20  0.115134  0.954800   0.954011  0.955633  0.110945       0.95820
# 21  0.106921  0.958800   0.958280  0.959335  0.105213       0.96010
# 22  0.105710  0.959487   0.958772  0.960235  0.109344       0.95920
# 23  0.108343  0.957250   0.956549  0.957984  0.101886       0.96135
# 24  0.104445  0.958488   0.958117  0.958860  0.142297       0.94400
# 25  0.100803  0.960525   0.959453  0.961661  0.104862       0.96125
# 26  0.096040  0.962438   0.961765  0.963136  0.104015       0.96165
# 27  0.094728  0.963600   0.962661  0.964587  0.103750       0.96060
# 28  0.089857  0.965875   0.965118  0.966663  0.106306       0.96045
# 29  0.088087  0.965150   0.964440  0.965887  0.111397       0.95950
# 30  0.087960  0.965612   0.964426  0.966863  0.102589       0.96295
# 31  0.084595  0.967587   0.966677  0.968538  0.096305       0.96355
# 32  0.083476  0.967800   0.966714  0.968938  0.098811       0.96430
# 33  0.078529  0.969625   0.968863  0.970414  0.101480       0.96205
# 34  0.078878  0.969863   0.968270  0.971539  0.093372       0.96650
# 35  0.075826  0.971388   0.970682  0.972115  0.099204       0.96410
# 36  0.073826  0.971462   0.970170  0.972815  0.107067       0.96135
# 37  0.073165  0.971900   0.970595  0.973265  0.100878       0.96425
# 38  0.069378  0.973175   0.972692  0.973665  0.109396       0.96055
# 39  0.069658  0.973500   0.973277  0.973715  0.104978       0.96345
# 40  0.067628  0.974288   0.973036  0.975591  0.098998       0.96395
# 41  0.064739  0.974875   0.973799  0.975991  0.096385       0.96535
# 42  0.064408  0.975412   0.974703  0.976141  0.104610       0.96175
# 43  0.062979  0.976000   0.974567  0.977492  0.096335       0.96535
# 44  0.056702  0.977962   0.977155  0.978792  0.100406       0.96495
#
#     val_precision  val_recall
# 0        0.874607    0.860110
# 1        0.932468    0.860310
# 2        0.905358    0.924613
# 3        0.933882    0.906840
# 4        0.926569    0.943684
# 5        0.954474    0.904343
# 6        0.940285    0.922916
# 7        0.942249    0.949775
# 8        0.960675    0.931802
# 9        0.936233    0.954368
# 10       0.967921    0.906840
# 11       0.955958    0.949276
# 12       0.959626    0.923215
# 13       0.945872    0.963155
# 14       0.948920    0.960859
# 15       0.939731    0.954368
# 16       0.966075    0.935497
# 17       0.960585    0.951473
# 18       0.964000    0.951872
# 19       0.958736    0.951173
# 20       0.949642    0.967848
# 21       0.968106    0.951672
# 22       0.972082    0.945681
# 23       0.957163    0.966051
# 24       0.925069    0.966450
# 25       0.955442    0.967748
# 26       0.949194    0.975637
# 27       0.960567    0.960759
# 28       0.963052    0.957763
# 29       0.941996    0.979431
# 30       0.964164    0.961757
# 31       0.967197    0.959760
# 32       0.959672    0.969446
# 33       0.964845    0.959161
# 34       0.963680    0.969646
# 35       0.970353    0.957564
# 36       0.946042    0.978632
# 37       0.968845    0.959461
# 38       0.962781    0.958263
# 39       0.955187    0.972641
# 40       0.962296    0.965851
# 41       0.959937    0.971343
# 42       0.947638    0.977634
# 43       0.962401    0.968647
# 44       0.961729    0.968547

# %% [markdown]
# ## CNN Feature Map

# %%
for layer in cnn_model.layers:

    if 'conv' not in layer.name:
        continue
    filters , bias = layer.get_weights()
    print(layer.name , filters.shape)
# Out:
# conv2d (3, 3, 3, 64)
# conv2d_1 (3, 3, 64, 128)
# conv2d_2 (3, 3, 128, 256)

# %%
filters , bias = cnn_model.layers[1].get_weights()

# %%
f_min, f_max = filters.min(), filters.max()
filters = (filters - f_min) / (f_max - f_min)

# %%
n_filters =6
ix=1
fig = plt.figure(figsize=(20,15))
for i in range(n_filters):
    # get the filters
    f = filters[:,:,:,i]
    for j in range(3):
        # subplot for 6 filters and 3 channels
        plt.subplot(n_filters,3,ix)
        plt.imshow(f[:,:,j] ,cmap='gray')
        ix+=1
#plot the filters
plt.show()

# %%
modelmap = Model(inputs=cnn_model.inputs , outputs=cnn_model.layers[1].output)

# %%
for i in range(len(cnn_model.layers)):
    layer = cnn_model.layers[i]
    if 'conv' not in layer.name:
        continue
    print(i , layer.name , layer.output.shape)
# Out:
# 1 conv2d (None, 32, 32, 64)
# 4 conv2d_1 (None, 16, 16, 128)
# 7 conv2d_2 (None, 8, 8, 256)

# %%
train.take(1)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
features = modelmap.predict(train.take(1))

features.shape
# Out:
# 1/1 [==============================] - 0s 183ms/step
# (500, 32, 32, 64)

# %%
fig = plt.figure(figsize=(20,15))
for i in range(1,features.shape[3]+1):

    plt.subplot(8,8,i)
    plt.imshow(features[0,:,:,i-1] , cmap='gray')

plt.show()

# %%
blocks = [1, 2]
outputs = [modelmap.layers[i].output for i in blocks]

model2 = Model(inputs= modelmap.inputs, outputs = outputs)

# %%
feature_map = model2.predict(train.take(1))

len(feature_map[0][0][0][0])
# Out:
# 1/1 [==============================] - 0s 135ms/step
# 3

# %%
for i,fmap in zip(blocks,feature_map):
    fig = plt.figure(figsize=(20,15))
    #https://stackoverflow.com/a/12444777
    fig.suptitle("BLOCK_{}".format(i) , fontsize=20)
    for i in range(1,features.shape[3]):

        plt.subplot(8,8,i)
        plt.imshow(fmap[0,:,:,i-1] , cmap='gray')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-66-4aee08f4166c> in <cell line: 1>()
#       6
#       7         plt.subplot(8,8,i)
# ----> 8         plt.imshow(fmap[0,:,:,i-1] , cmap='gray')
#       9
#      10 plt.show()
#
# IndexError: index 3 is out of bounds for axis 3 with size 3

# %% [markdown]
# ## AlexNet Architecture

# %%
alex_model = Sequential([
    layers.Rescaling(1./255, input_shape=(32,32,3)),
    layers.Resizing(227,227),
    layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.BatchNormalization(),
    layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.BatchNormalization(),
    layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    layers.BatchNormalization(),
    layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    layers.Flatten(),
    layers.Dense(4096, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(4096, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(1, activation='sigmoid')
])
alex_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_1 (Rescaling)     (None, 32, 32, 3)         0
#
#  resizing (Resizing)         (None, 227, 227, 3)       0
#
#  conv2d_3 (Conv2D)           (None, 55, 55, 96)        34944
#
#  batch_normalization (Batch  (None, 55, 55, 96)        384
#  Normalization)
#
#  max_pooling2d_3 (MaxPoolin  (None, 27, 27, 96)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 27, 27, 256)       614656
#
#  batch_normalization_1 (Bat  (None, 27, 27, 256)       1024
#  chNormalization)
#
#  max_pooling2d_4 (MaxPoolin  (None, 13, 13, 256)       0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 13, 13, 384)       885120
#
#  batch_normalization_2 (Bat  (None, 13, 13, 384)       1536
#  chNormalization)
#
#  conv2d_6 (Conv2D)           (None, 13, 13, 384)       1327488
#
#  batch_normalization_3 (Bat  (None, 13, 13, 384)       1536
#  chNormalization)
#
#  conv2d_7 (Conv2D)           (None, 13, 13, 256)       884992
#
#  batch_normalization_4 (Bat  (None, 13, 13, 256)       1024
#  chNormalization)
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 256)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9216)              0
#
#  dense_2 (Dense)             (None, 4096)              37752832
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 4096)              16781312
#
#  dropout_4 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 58290945 (222.36 MB)
# Trainable params: 58288193 (222.35 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________

# %%
alex_model.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy", metrics.Precision(name="precision"), metrics.Recall(name="recall")])
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

# %%
epochs = 40

history = alex_model.fit(
  train,
  validation_data=val,
  epochs=epochs,
  verbose=3, callbacks=[es])

history = pd.DataFrame(history.history)
display(history)
# Out:
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
#         loss  accuracy  precision    recall  val_loss  val_accuracy  \
# 0   1.594628  0.735162   0.734623  0.736001  0.613416       0.65045
# 1   0.357891  0.843100   0.840385  0.846943  1.341088       0.51415
# 2   0.271160  0.887388   0.885523  0.889709  1.316888       0.55490
# 3   0.216745  0.914525   0.914141  0.914918  0.315215       0.86280
# 4   0.190947  0.925600   0.925296  0.925897  0.217075       0.91330
# 5   0.176344  0.931925   0.932072  0.931699  0.233013       0.90300
# 6   0.159572  0.938438   0.938250  0.938602  0.246384       0.90295
# 7   0.146616  0.944225   0.943982  0.944454  0.191860       0.92315
# 8   0.135982  0.948375   0.948670  0.948005  0.161001       0.94110
# 9   0.126327  0.952175   0.952406  0.951882  0.213978       0.92015
# 10  0.116344  0.956000   0.956166  0.955783  0.197490       0.92725
# 11  0.110986  0.957550   0.957832  0.957209  0.425310       0.83920
# 12  0.106261  0.960125   0.961102  0.959035  0.375987       0.86050
# 13  0.100062  0.962237   0.963069  0.961311  0.185418       0.92865
#
#     val_precision  val_recall
# 0        0.628288    0.739391
# 1        0.507579    0.996405
# 2        0.529430    0.999601
# 3        0.829332    0.914129
# 4        0.944498    0.878482
# 5        0.936062    0.865402
# 6        0.950056    0.850924
# 7        0.909328    0.940290
# 8        0.938822    0.943884
# 9        0.959899    0.877184
# 10       0.974291    0.877883
# 11       0.965494    0.704044
# 12       0.963200    0.750075
# 13       0.917623    0.942087

# %% [markdown]
# ## VGG

# %%
from keras.applications import VGG16
from keras.applications.vgg16 import preprocess_input

def preprocess(x, y):
    return preprocess_input(x), y

trainv = train.map(preprocess)
valv = val.map(preprocess)
testv = test.map(preprocess)

trainv_list = list(trainv)
trainv_imgs = trainv_list[0][0].numpy()
trainv_labels = trainv_list[0][1].numpy()

valv_list = list(valv)
valv_imgs = valv_list[0][0].numpy()
valv_labels = valv_list[0][1].numpy()

testv_list = list(testv)
testv_imgs = testv_list[0][0].numpy()
testv_labels = testv_list[0][1].numpy()



# build model
vgg16 = VGG16(input_shape=(32,32,3), weights='imagenet', include_top=False)
# Freeze all but the last 3 layers
for layer in vgg16.layers[:-3]:
  layer.trainable = False
input = vgg16.layers[-1].output # input is the last output from vgg16

x = Dropout(0.25)(input)
x = Flatten()(x)
output = Dense(1, activation='sigmoid')(x)

# create the model
vgg16_model = Model(vgg16.input, output, name='VGG16_Model')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 3s 0us/step

# %%
vgg16_model.compile(optimizer= SGD(learning_rate=1e-3), loss= 'binary_crossentropy', metrics= ['accuracy'])


# Train model
history = vgg16_model.fit(trainv,
                validation_data=valv,
                epochs= 40, callbacks= es)
history = pd.DataFrame(history.history)
display(history)
# Out:
# Epoch 1/40
# 160/160 [==============================] - 7s 30ms/step - loss: 0.7846 - accuracy: 0.7440 - val_loss: 0.3779 - val_accuracy: 0.8395
# Epoch 2/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.3952 - accuracy: 0.8264 - val_loss: 0.3287 - val_accuracy: 0.8579
# Epoch 3/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.3480 - accuracy: 0.8487 - val_loss: 0.2965 - val_accuracy: 0.8737
# Epoch 4/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.3218 - accuracy: 0.8615 - val_loss: 0.2719 - val_accuracy: 0.8882
# Epoch 5/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.3032 - accuracy: 0.8702 - val_loss: 0.2661 - val_accuracy: 0.8885
# Epoch 6/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2888 - accuracy: 0.8786 - val_loss: 0.2561 - val_accuracy: 0.8957
# Epoch 7/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2795 - accuracy: 0.8818 - val_loss: 0.2478 - val_accuracy: 0.8971
# Epoch 8/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.2687 - accuracy: 0.8871 - val_loss: 0.2428 - val_accuracy: 0.8993
# Epoch 9/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.2589 - accuracy: 0.8923 - val_loss: 0.2382 - val_accuracy: 0.9020
# Epoch 10/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2516 - accuracy: 0.8953 - val_loss: 0.2343 - val_accuracy: 0.9043
# Epoch 11/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2455 - accuracy: 0.8983 - val_loss: 0.2297 - val_accuracy: 0.9068
# Epoch 12/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2395 - accuracy: 0.9006 - val_loss: 0.2266 - val_accuracy: 0.9078
# Epoch 13/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2339 - accuracy: 0.9030 - val_loss: 0.2261 - val_accuracy: 0.9089
# Epoch 14/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2294 - accuracy: 0.9064 - val_loss: 0.2216 - val_accuracy: 0.9114
# Epoch 15/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2238 - accuracy: 0.9075 - val_loss: 0.2177 - val_accuracy: 0.9100
# Epoch 16/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.2186 - accuracy: 0.9105 - val_loss: 0.2149 - val_accuracy: 0.9127
# Epoch 17/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2168 - accuracy: 0.9110 - val_loss: 0.2138 - val_accuracy: 0.9137
# Epoch 18/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2123 - accuracy: 0.9135 - val_loss: 0.2159 - val_accuracy: 0.9105
# Epoch 19/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2107 - accuracy: 0.9130 - val_loss: 0.2100 - val_accuracy: 0.9137
# Epoch 20/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2044 - accuracy: 0.9163 - val_loss: 0.2118 - val_accuracy: 0.9153
# Epoch 21/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.2030 - accuracy: 0.9182 - val_loss: 0.2070 - val_accuracy: 0.9175
# Epoch 22/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1986 - accuracy: 0.9198 - val_loss: 0.2071 - val_accuracy: 0.9193
# Epoch 23/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1956 - accuracy: 0.9210 - val_loss: 0.2056 - val_accuracy: 0.9171
# Epoch 24/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1934 - accuracy: 0.9206 - val_loss: 0.2090 - val_accuracy: 0.9131
# Epoch 25/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1901 - accuracy: 0.9222 - val_loss: 0.2059 - val_accuracy: 0.9165
# Epoch 26/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1872 - accuracy: 0.9241 - val_loss: 0.2010 - val_accuracy: 0.9197
# Epoch 27/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1844 - accuracy: 0.9249 - val_loss: 0.2046 - val_accuracy: 0.9165
# Epoch 28/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1807 - accuracy: 0.9275 - val_loss: 0.2001 - val_accuracy: 0.9216
# Epoch 29/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1775 - accuracy: 0.9286 - val_loss: 0.1988 - val_accuracy: 0.9213
# Epoch 30/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1768 - accuracy: 0.9281 - val_loss: 0.2060 - val_accuracy: 0.9208
# Epoch 31/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1754 - accuracy: 0.9284 - val_loss: 0.1932 - val_accuracy: 0.9230
# Epoch 32/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1713 - accuracy: 0.9313 - val_loss: 0.1969 - val_accuracy: 0.9213
# Epoch 33/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1700 - accuracy: 0.9314 - val_loss: 0.2063 - val_accuracy: 0.9203
# Epoch 34/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1688 - accuracy: 0.9318 - val_loss: 0.1944 - val_accuracy: 0.9248
# Epoch 35/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1656 - accuracy: 0.9328 - val_loss: 0.1939 - val_accuracy: 0.9251
# Epoch 36/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1625 - accuracy: 0.9352 - val_loss: 0.1903 - val_accuracy: 0.9250
# Epoch 37/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1609 - accuracy: 0.9359 - val_loss: 0.1949 - val_accuracy: 0.9243
# Epoch 38/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1590 - accuracy: 0.9360 - val_loss: 0.1894 - val_accuracy: 0.9258
# Epoch 39/40
# 160/160 [==============================] - 5s 28ms/step - loss: 0.1581 - accuracy: 0.9365 - val_loss: 0.1972 - val_accuracy: 0.9196
# Epoch 40/40
# 160/160 [==============================] - 5s 29ms/step - loss: 0.1541 - accuracy: 0.9376 - val_loss: 0.1937 - val_accuracy: 0.9255
#         loss  accuracy  val_loss  val_accuracy
# 0   0.784552  0.743988  0.377923       0.83945
# 1   0.395164  0.826388  0.328669       0.85785
# 2   0.347985  0.848713  0.296467       0.87375
# 3   0.321848  0.861450  0.271920       0.88825
# 4   0.303201  0.870225  0.266123       0.88850
# 5   0.288839  0.878600  0.256114       0.89575
# 6   0.279538  0.881813  0.247836       0.89710
# 7   0.268716  0.887125  0.242837       0.89935
# 8   0.258890  0.892338  0.238224       0.90200
# 9   0.251559  0.895250  0.234282       0.90435
# 10  0.245497  0.898313  0.229670       0.90685
# 11  0.239538  0.900638  0.226600       0.90775
# 12  0.233946  0.903025  0.226142       0.90895
# 13  0.229387  0.906412  0.221563       0.91140
# 14  0.223801  0.907525  0.217685       0.90995
# 15  0.218636  0.910475  0.214946       0.91270
# 16  0.216829  0.910963  0.213772       0.91370
# 17  0.212279  0.913475  0.215882       0.91055
# 18  0.210671  0.913037  0.209950       0.91370
# 19  0.204437  0.916275  0.211766       0.91530
# 20  0.203042  0.918212  0.206982       0.91750
# 21  0.198569  0.919762  0.207094       0.91925
# 22  0.195559  0.920963  0.205626       0.91705
# 23  0.193392  0.920613  0.209032       0.91310
# 24  0.190110  0.922150  0.205898       0.91650
# 25  0.187249  0.924075  0.201011       0.91970
# 26  0.184439  0.924887  0.204560       0.91650
# 27  0.180724  0.927450  0.200103       0.92165
# 28  0.177545  0.928625  0.198836       0.92130
# 29  0.176775  0.928150  0.205982       0.92085
# 30  0.175407  0.928375  0.193183       0.92295
# 31  0.171262  0.931262  0.196894       0.92130
# 32  0.170024  0.931437  0.206291       0.92030
# 33  0.168814  0.931800  0.194388       0.92480
# 34  0.165631  0.932800  0.193948       0.92510
# 35  0.162480  0.935225  0.190330       0.92495
# 36  0.160948  0.935862  0.194932       0.92430
# 37  0.158988  0.936000  0.189423       0.92575
# 38  0.158148  0.936512  0.197179       0.91960
# 39  0.154096  0.937625  0.193732       0.92550

# %%
for layer in vgg16.layers[:-3]:
  layer.trainable = True

vgg16_model.compile(optimizer= SGD(learning_rate=1e-4), loss= 'binary_crossentropy', metrics= ['accuracy'])

# reinitialize callbacks
#checkpoint = ModelCheckpoint('VggModel.weights.hdf5', monitor='val_loss', verbose=1,save_best_only=True, mode= 'min')

#callbacks= [reduceLR, early_stopping,checkpoint]

# Train model
history = vgg16_model.fit(trainv,
                validation_data=valv,
                epochs= 40, verbose = 3, callbacks= es)
history = pd.DataFrame(history.history)
display(history)
# Out:
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
#         loss  accuracy  val_loss  val_accuracy
# 0   0.147398  0.941125  0.186068       0.92695
# 1   0.144026  0.942550  0.185175       0.92810
# 2   0.142511  0.943550  0.184151       0.92865
# 3   0.140014  0.944812  0.182824       0.92915
# 4   0.139726  0.944550  0.181608       0.92985
# 5   0.138421  0.944350  0.181224       0.93005
# 6   0.138091  0.944987  0.180599       0.93025
# 7   0.134789  0.945700  0.180044       0.93055
# 8   0.134007  0.947275  0.179322       0.93130
# 9   0.131747  0.948563  0.178231       0.93185
# 10  0.131995  0.947812  0.177221       0.93195
# 11  0.129718  0.948313  0.177287       0.93245
# 12  0.129870  0.947688  0.175700       0.93280
# 13  0.127153  0.949450  0.177817       0.93340
# 14  0.126752  0.949313  0.175400       0.93345
# 15  0.126373  0.951038  0.175515       0.93375
# 16  0.124904  0.950175  0.174754       0.93400
# 17  0.124687  0.950962  0.173925       0.93375
# 18  0.123868  0.950662  0.173564       0.93425
# 19  0.124426  0.951113  0.172526       0.93450
# 20  0.122137  0.951750  0.172230       0.93510
# 21  0.120842  0.952412  0.172171       0.93550
# 22  0.120155  0.952750  0.171754       0.93550
# 23  0.118581  0.953025  0.171168       0.93580
# 24  0.119151  0.952987  0.171144       0.93595
# 25  0.116847  0.954225  0.170217       0.93610
# 26  0.116873  0.954425  0.170430       0.93620
# 27  0.115557  0.955037  0.170791       0.93670
# 28  0.115561  0.954675  0.170762       0.93680
# 29  0.113549  0.955187  0.170425       0.93765
# 30  0.113878  0.954975  0.169483       0.93770
# 31  0.111877  0.955350  0.168727       0.93810
# 32  0.110863  0.956062  0.169052       0.93775
# 33  0.112202  0.955487  0.168775       0.93815
# 34  0.109842  0.956487  0.168912       0.93785
# 35  0.109134  0.956800  0.167817       0.93800
# 36  0.108150  0.957287  0.167588       0.93855
# 37  0.107442  0.957488  0.166844       0.93805
# 38  0.106640  0.958475  0.167610       0.93815
# 39  0.107777  0.957825  0.167829       0.93890

# %% [markdown]
# ##Modified Ensemble

# %%
models = [cnn_model, alex_model, vgg16_model]

input = Input(shape=(32, 32, 3), name='input') # input layer

# get output for each model input
outputs = [model(input) for model in models]

# contenate the ouputs
x = Concatenate()(outputs)

# add further layers
x = Dropout(0.5)(x)
output = Dense(1, activation='sigmoid', name='output')(x) # output layer

# create concatenated model
conc_model = Model(input, output, name= 'Concatenated_Model')

# %%
from tensorflow.keras.utils import plot_model
plot_model(conc_model)

# %%
conc_model.compile(loss="binary_crossentropy",
                optimizer="adam",
                metrics=["accuracy", metrics.Precision(name="precision"), metrics.Recall(name="recall")])
history = conc_model.fit(train,
                validation_data=val,
                epochs= 40, callbacks= es)
# Out:
# Epoch 1/40
# 160/160 [==============================] - 51s 265ms/step - loss: 0.6462 - accuracy: 0.5909 - precision: 0.6014 - recall: 0.5382 - val_loss: 0.5937 - val_accuracy: 0.5132 - val_precision: 0.9730 - val_recall: 0.0288
# Epoch 2/40
# 160/160 [==============================] - 42s 260ms/step - loss: 0.6087 - accuracy: 0.6385 - precision: 0.6276 - recall: 0.6803 - val_loss: 0.5417 - val_accuracy: 0.9455 - val_precision: 0.9716 - val_recall: 0.9180
# Epoch 3/40
# 160/160 [==============================] - 41s 258ms/step - loss: 0.5898 - accuracy: 0.6444 - precision: 0.6320 - recall: 0.6905 - val_loss: 0.5201 - val_accuracy: 0.9424 - val_precision: 0.9758 - val_recall: 0.9074
# Epoch 4/40
# 160/160 [==============================] - 42s 260ms/step - loss: 0.5722 - accuracy: 0.6533 - precision: 0.6449 - recall: 0.6820 - val_loss: 0.5010 - val_accuracy: 0.9558 - val_precision: 0.9567 - val_recall: 0.9550
# Epoch 5/40
# 160/160 [==============================] - 42s 260ms/step - loss: 0.5648 - accuracy: 0.6223 - precision: 0.6017 - recall: 0.7228 - val_loss: 0.4895 - val_accuracy: 0.9578 - val_precision: 0.9568 - val_recall: 0.9592
# Epoch 6/40
# 160/160 [==============================] - 41s 258ms/step - loss: 0.5538 - accuracy: 0.6816 - precision: 0.7227 - recall: 0.5888 - val_loss: 0.4789 - val_accuracy: 0.9488 - val_precision: 0.9311 - val_recall: 0.9694
# Epoch 7/40
# 160/160 [==============================] - 41s 258ms/step - loss: 0.5502 - accuracy: 0.7252 - precision: 0.9497 - recall: 0.4753 - val_loss: 0.4653 - val_accuracy: 0.9530 - val_precision: 0.9403 - val_recall: 0.9674
# Epoch 8/40
# 160/160 [==============================] - 41s 258ms/step - loss: 0.5390 - accuracy: 0.7301 - precision: 0.9581 - recall: 0.4809 - val_loss: 0.4567 - val_accuracy: 0.9481 - val_precision: 0.9490 - val_recall: 0.9473
# Epoch 9/40
# 160/160 [==============================] - 41s 258ms/step - loss: 0.5341 - accuracy: 0.7288 - precision: 0.9605 - recall: 0.4769 - val_loss: 0.4438 - val_accuracy: 0.9510 - val_precision: 0.9686 - val_recall: 0.9324
# Epoch 10/40
# 160/160 [==============================] - 42s 260ms/step - loss: 0.5290 - accuracy: 0.7309 - precision: 0.9612 - recall: 0.4810 - val_loss: 0.4322 - val_accuracy: 0.9534 - val_precision: 0.9500 - val_recall: 0.9574

# %%
history = pd.DataFrame(history.history)

plt.plot(range(len(history)), history["accuracy"], label="Training Accuracy")
plt.plot(range(len(history)), history["val_accuracy"], label="Validation Accuracy")
plt.legend(loc="lower right")
plt.title("Training and Validation Accuracy")
plt.show()

# %%
conc_model.evaluate(test, return_dict=True)
# Out:
# 40/40 [==============================] - 3s 62ms/step - loss: 0.4904 - accuracy: 0.9561 - precision: 0.9574 - recall: 0.9548
# {'loss': 0.4904259145259857,
#  'accuracy': 0.9561499953269958,
#  'precision': 0.9573849439620972,
#  'recall': 0.954800009727478}

# %%
conc_model.evaluate(train, return_dict=True)
# Out:
# 160/160 [==============================] - 10s 62ms/step - loss: 0.4800 - accuracy: 0.9769 - precision: 0.9769 - recall: 0.9768
# {'loss': 0.4800218343734741,
#  'accuracy': 0.9768624901771545,
#  'precision': 0.9768896102905273,
#  'recall': 0.9768162965774536}

# %%
classes = train.class_names
classes
# Out:
# ['FAKE', 'REAL']

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
preds = conc_model.predict(test)
preds
# Out:
# 40/40 [==============================] - 3s 59ms/step
# array([[0.69083744],
#        [0.43115968],
#        [0.6908394 ],
#        ...,
#        [0.6824795 ],
#        [0.6040329 ],
#        [0.43115968]], dtype=float32)

# %%
test_predictions = np.array([])
test_check = np.array([])
for x, y in test:
    test_predictions = np.append(test_predictions, conc_model(x) > 0.5)
    test_check = np.append(test_check, y)
confusion_matrix(test_check, test_predictions)
# Out:
# array([[9575,  425],
#        [ 452, 9548]])

# %%
import seaborn as sns
ax = sns.heatmap(confusion_matrix(test_check, test_predictions), annot=True, fmt='.0f', cmap='Blues', xticklabels=classes, yticklabels=classes,
                  cbar=False)
ax.set(xlabel='Predicted Label', ylabel='True Label')
plt.show()
